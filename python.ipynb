# %% [markdown]
# <a href="https://colab.research.google.com/github/Larissa9512/Primeira/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 1

# %%
ano = "IV"
print(ano,"competição de programação dá Start")
# Out:
# I competição de programação dá Start

# %% [markdown]
# aula 2

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais de ana são {pontos_ana}")
print(f"Os pontos de ana e rodrigo são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais de ana são 46
# Os pontos de ana e rodrigo são 70

# %% [markdown]
# aula 3

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
figurinhas_joao = 2 * figurinhas_amigo
figurinhas_extras = int(input("Digite o número de amigos: "))
figurinhas_extras = figurinhas_extras // (numero_de_amigos + 2)
figurinhas_joao2 = figurinhas_extras * 2
print(f"João recebeu {figurinhas_joao} figurinhas extras")
# Out:
# Digite o total de figurinhas: 10
# Digite o número de amigos: 2
# Digite o número de amigos: 10
# João recebeu 4 figurinhas extras

# %% [markdown]
# #**Aula 4**    ❤  ✳  ⏰
#
# ##dia de prova
#
#
# > Adicionar aspas
